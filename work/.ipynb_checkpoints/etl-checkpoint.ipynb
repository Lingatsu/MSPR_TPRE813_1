# %% [markdown]
# # TEPEDELEN Léo DELLARICA Steven BARBIN Kevin

# %% [markdown]
# # Projet EISI1 Capgemini MSPRTPRE813_1

# %% [markdown]
# Ce notebook Python est le rapport détaillé et l'ETL de notre projet. La suite du rapport se situe après l'ETL, nous y détaillons le fonctionnement du reste du système.

# %% [markdown]
# Il a été réalisé à l'aide de Docker afin d'en faciliter le déploiement pour tester et collaborer.

# %% [markdown]
# Vous trouverez tout ce qu'il vous faut pour essayer le programme sur votre machine dans le fichier README de ce repository github :

# %% [markdown]
# # Extraire les données dans un DataFrame pySpark

# %%
from pyspark.sql import SparkSession

# Créer une session Spark
spark = SparkSession.builder.appName("example").getOrCreate()

# Lire le fichier CSV
df = spark.read.option("sep", "\t").csv("data/en.openfoodfacts.org.products.csv.gz", header=True, inferSchema=True).cache()

# %%
print("Nombre de lignes dans le fichier de base : " + str(df.count()))
# Out:
# Nombre de lignes dans le fichier de base : 3400990

# %%
import pandas as pd

# %%
df_demographie = pd.read_stata('data/popcommunes.dta')
# Out:
# /tmp/ipykernel_150/2387175649.py:1: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df_demographie = pd.read_stata('data/popcommunes.dta')

# %%
df_demographie.columns.to_list()
# Out:
# ['dep',
#  'nomdep',
#  'codecommune',
#  'nomcommune',
#  'paris',
#  'reg',
#  'nomreg',
#  'codeagglo',
#  'nomagglo',
#  'multicommune',
#  'numcommune',
#  'popagglo1780',
#  'popagglo1781',
#  'popagglo1782',
#  'popagglo1783',
#  'popagglo1784',
#  'popagglo1785',
#  'popagglo1786',
#  'popagglo1787',
#  'popagglo1788',
#  'popagglo1789',
#  'popagglo1790',
#  'popagglo1791',
#  'popagglo1792',
#  'popagglo1793',
#  'popagglo1794',
#  'popagglo1795',
#  'popagglo1796',
#  'popagglo1797',
#  'popagglo1798',
#  'popagglo1799',
#  'popagglo1800',
#  'popagglo1801',
#  'popagglo1802',
#  'popagglo1803',
#  'popagglo1804',
#  'popagglo1805',
#  'popagglo1806',
#  'popagglo1807',
#  'popagglo1808',
#  'popagglo1809',
#  'popagglo1810',
#  'popagglo1811',
#  'popagglo1812',
#  'popagglo1813',
#  'popagglo1814',
#  'popagglo1815',
#  'popagglo1816',
#  'popagglo1817',
#  'popagglo1818',
#  'popagglo1819',
#  'popagglo1820',
#  'popagglo1821',
#  'popagglo1822',
#  'popagglo1823',
#  'popagglo1824',
#  'popagglo1825',
#  'popagglo1826',
#  'popagglo1827',
#  'popagglo1828',
#  'popagglo1829',
#  'popagglo1830',
#  'popagglo1831',
#  'popagglo1832',
#  'popagglo1833',
#  'popagglo1834',
#  'popagglo1835',
#  'popagglo1836',
#  'popagglo1837',
#  'popagglo1838',
#  'popagglo1839',
#  'popagglo1840',
#  'popagglo1841',
#  'popagglo1842',
#  'popagglo1843',
#  'popagglo1844',
#  'popagglo1845',
#  'popagglo1846',
#  'popagglo1847',
#  'popagglo1848',
#  'popagglo1849',
#  'popagglo1850',
#  'popagglo1851',
#  'popagglo1852',
#  'popagglo1853',
#  'popagglo1854',
#  'popagglo1855',
#  'popagglo1856',
#  'popagglo1857',
#  'popagglo1858',
#  'popagglo1859',
#  'popagglo1860',
#  'popagglo1861',
#  'popagglo1862',
#  'popagglo1863',
#  'popagglo1864',
#  'popagglo1865',
#  'popagglo1866',
#  'popagglo1867',
#  'popagglo1868',
#  'popagglo1869',
#  'popagglo1870',
#  'popagglo1871',
#  'popagglo1872',
#  'popagglo1873',
#  'popagglo1874',
#  'popagglo1875',
#  'popagglo1876',
#  'popagglo1877',
#  'popagglo1878',
#  'popagglo1879',
#  'popagglo1880',
#  'popagglo1881',
#  'popagglo1882',
#  'popagglo1883',
#  'popagglo1884',
#  'popagglo1885',
#  'popagglo1886',
#  'popagglo1887',
#  'popagglo1888',
#  'popagglo1889',
#  'popagglo1890',
#  'popagglo1891',
#  'popagglo1892',
#  'popagglo1893',
#  'popagglo1894',
#  'popagglo1895',
#  'popagglo1896',
#  'popagglo1897',
#  'popagglo1898',
#  'popagglo1899',
#  'popagglo1900',
#  'popagglo1901',
#  'popagglo1902',
#  'popagglo1903',
#  'popagglo1904',
#  'popagglo1905',
#  'popagglo1906',
#  'popagglo1907',
#  'popagglo1908',
#  'popagglo1909',
#  'popagglo1910',
#  'popagglo1911',
#  'popagglo1912',
#  'popagglo1913',
#  'popagglo1914',
#  'popagglo1915',
#  'popagglo1916',
#  'popagglo1917',
#  'popagglo1918',
#  'popagglo1919',
#  'popagglo1920',
#  'popagglo1921',
#  'popagglo1922',
#  'popagglo1923',
#  'popagglo1924',
#  'popagglo1925',
#  'popagglo1926',
#  'popagglo1927',
#  'popagglo1928',
#  'popagglo1929',
#  'popagglo1930',
#  'popagglo1931',
#  'popagglo1932',
#  'popagglo1933',
#  'popagglo1934',
#  'popagglo1935',
#  'popagglo1936',
#  'popagglo1937',
#  'popagglo1938',
#  'popagglo1939',
#  'popagglo1940',
#  'popagglo1941',
#  'popagglo1942',
#  'popagglo1943',
#  'popagglo1944',
#  'popagglo1945',
#  'popagglo1946',
#  'popagglo1947',
#  'popagglo1948',
#  'popagglo1949',
#  'popagglo1950',
#  'popagglo1951',
#  'popagglo1952',
#  'popagglo1953',
#  'popagglo1954',
#  'popagglo1955',
#  'popagglo1956',
#  'popagglo1957',
#  'popagglo1958',
#  'popagglo1959',
#  'popagglo1960',
#  'popagglo1961',
#  'popagglo1962',
#  'popagglo1963',
#  'popagglo1964',
#  'popagglo1965',
#  'popagglo1966',
#  'popagglo1967',
#  'popagglo1968',
#  'popagglo1969',
#  'popagglo1970',
#  'popagglo1971',
#  'popagglo1972',
#  'popagglo1973',
#  'popagglo1974',
#  'popagglo1975',
#  'popagglo1976',
#  'popagglo1977',
#  'popagglo1978',
#  'popagglo1979',
#  'popagglo1980',
#  'popagglo1981',
#  'popagglo1982',
#  'popagglo1983',
#  'popagglo1984',
#  'popagglo1985',
#  'popagglo1986',
#  'popagglo1987',
#  'popagglo1988',
#  'popagglo1989',
#  'popagglo1990',
#  'popagglo1991',
#  'popagglo1992',
#  'popagglo1993',
#  'popagglo1994',
#  'popagglo1995',
#  'popagglo1996',
#  'popagglo1997',
#  'popagglo1998',
#  'popagglo1999',
#  'popagglo2000',
#  'popagglo2001',
#  'popagglo2002',
#  'popagglo2003',
#  'popagglo2004',
#  'popagglo2005',
#  'popagglo2006',
#  'popagglo2007',
#  'popagglo2008',
#  'popagglo2009',
#  'popagglo2010',
#  'popagglo2011',
#  'popagglo2012',
#  'popagglo2013',
#  'popagglo2014',
#  'popagglo2015',
#  'popagglo2016',
#  'popagglo2017',
#  'popagglo2018',
#  'popagglo2019',
#  'popagglo2020',
#  'popagglo2021',
#  'popagglo2022',
#  'pop1780',
#  'pop1781',
#  'pop1782',
#  'pop1783',
#  'pop1784',
#  'pop1785',
#  'pop1786',
#  'pop1787',
#  'pop1788',
#  'pop1789',
#  'pop1790',
#  'pop1791',
#  'pop1792',
#  'pop1793',
#  'pop1794',
#  'pop1795',
#  'pop1796',
#  'pop1797',
#  'pop1798',
#  'pop1799',
#  'pop1800',
#  'pop1801',
#  'pop1802',
#  'pop1803',
#  'pop1804',
#  'pop1805',
#  'pop1806',
#  'pop1807',
#  'pop1808',
#  'pop1809',
#  'pop1810',
#  'pop1811',
#  'pop1812',
#  'pop1813',
#  'pop1814',
#  'pop1815',
#  'pop1816',
#  'pop1817',
#  'pop1818',
#  'pop1819',
#  'pop1820',
#  'pop1821',
#  'pop1822',
#  'pop1823',
#  'pop1824',
#  'pop1825',
#  'pop1826',
#  'pop1827',
#  'pop1828',
#  'pop1829',
#  'pop1830',
#  'pop1831',
#  'pop1832',
#  'pop1833',
#  'pop1834',
#  'pop1835',
#  'pop1836',
#  'pop1837',
#  'pop1838',
#  'pop1839',
#  'pop1840',
#  'pop1841',
#  'pop1842',
#  'pop1843',
#  'pop1844',
#  'pop1845',
#  'pop1846',
#  'pop1847',
#  'pop1848',
#  'pop1849',
#  'pop1850',
#  'pop1851',
#  'pop1852',
#  'pop1853',
#  'pop1854',
#  'pop1855',
#  'pop1856',
#  'pop1857',
#  'pop1858',
#  'pop1859',
#  'pop1860',
#  'pop1861',
#  'pop1862',
#  'pop1863',
#  'pop1864',
#  'pop1865',
#  'pop1866',
#  'pop1867',
#  'pop1868',
#  'pop1869',
#  'pop1870',
#  'pop1871',
#  'pop1872',
#  'pop1873',
#  'pop1874',
#  'pop1875',
#  'pop1876',
#  'pop1877',
#  'pop1878',
#  'pop1879',
#  'pop1880',
#  'pop1881',
#  'pop1882',
#  'pop1883',
#  'pop1884',
#  'pop1885',
#  'pop1886',
#  'pop1887',
#  'pop1888',
#  'pop1889',
#  'pop1890',
#  'pop1891',
#  'pop1892',
#  'pop1893',
#  'pop1894',
#  'pop1895',
#  'pop1896',
#  'pop1897',
#  'pop1898',
#  'pop1899',
#  'pop1900',
#  'pop1901',
#  'pop1902',
#  'pop1903',
#  'pop1904',
#  'pop1905',
#  'pop1906',
#  'pop1907',
#  'pop1908',
#  'pop1909',
#  'pop1910',
#  'pop1911',
#  'pop1912',
#  'pop1913',
#  'pop1914',
#  'pop1915',
#  'pop1916',
#  'pop1917',
#  'pop1918',
#  'pop1919',
#  'pop1920',
#  'pop1921',
#  'pop1922',
#  'pop1923',
#  'pop1924',
#  'pop1925',
#  'pop1926',
#  'pop1927',
#  'pop1928',
#  'pop1929',
#  'pop1930',
#  'pop1931',
#  'pop1932',
#  'pop1933',
#  'pop1934',
#  'pop1935',
#  'pop1936',
#  'pop1937',
#  'pop1938',
#  'pop1939',
#  'pop1940',
#  'pop1941',
#  'pop1942',
#  'pop1943',
#  'pop1944',
#  'pop1945',
#  'pop1946',
#  'pop1947',
#  'pop1948',
#  'pop1949',
#  'pop1950',
#  'pop1951',
#  'pop1952',
#  'pop1953',
#  'pop1954',
#  'pop1955',
#  'pop1956',
#  'pop1957',
#  'pop1958',
#  'pop1959',
#  'pop1960',
#  'pop1961',
#  'pop1962',
#  'pop1963',
#  'pop1964',
#  'pop1965',
#  'pop1966',
#  'pop1967',
#  'pop1968',
#  'pop1969',
#  'pop1970',
#  'pop1971',
#  'pop1972',
#  'pop1973',
#  'pop1974',
#  'pop1975',
#  'pop1976',
#  'pop1977',
#  'pop1978',
#  'pop1979',
#  'pop1980',
#  'pop1981',
#  'pop1982',
#  'pop1983',
#  'pop1984',
#  'pop1985',
#  'pop1986',
#  'pop1987',
#  'pop1988',
#  'pop1989',
#  'pop1990',
#  'pop1991',
#  'pop1992',
#  'pop1993',
#  'pop1994',
#  'pop1995',
#  'pop1996',
#  'pop1997',
#  'pop1998',
#  'pop1999',
#  'pop2000',
#  'pop2001',
#  'pop2002',
#  'pop2003',
#  'pop2004',
#  'pop2005',
#  'pop2006',
#  'pop2007',
#  'pop2008',
#  'pop2009',
#  'pop2010',
#  'pop2011',
#  'pop2012',
#  'pop2013',
#  'pop2014',
#  'pop2015',
#  'pop2016',
#  'pop2017',
#  'pop2018',
#  'pop2019',
#  'pop2020',
#  'pop2021',
#  'pop2022',
#  'percommu1780',
#  'percommu1781',
#  'percommu1782',
#  'percommu1783',
#  'percommu1784',
#  'percommu1785',
#  'percommu1786',
#  'percommu1787',
#  'percommu1788',
#  'percommu1789',
#  'percommu1790',
#  'percommu1791',
#  'percommu1792',
#  'percommu1793',
#  'percommu1794',
#  'percommu1795',
#  'percommu1796',
#  'percommu1797',
#  'percommu1798',
#  'percommu1799',
#  'percommu1800',
#  'percommu1801',
#  'percommu1802',
#  'percommu1803',
#  'percommu1804',
#  'percommu1805',
#  'percommu1806',
#  'percommu1807',
#  'percommu1808',
#  'percommu1809',
#  'percommu1810',
#  'percommu1811',
#  'percommu1812',
#  'percommu1813',
#  'percommu1814',
#  'percommu1815',
#  'percommu1816',
#  'percommu1817',
#  'percommu1818',
#  'percommu1819',
#  'percommu1820',
#  'percommu1821',
#  'percommu1822',
#  'percommu1823',
#  'percommu1824',
#  'percommu1825',
#  'percommu1826',
#  'percommu1827',
#  'percommu1828',
#  'percommu1829',
#  'percommu1830',
#  'percommu1831',
#  'percommu1832',
#  'percommu1833',
#  'percommu1834',
#  'percommu1835',
#  'percommu1836',
#  'percommu1837',
#  'percommu1838',
#  'percommu1839',
#  'percommu1840',
#  'percommu1841',
#  'percommu1842',
#  'percommu1843',
#  'percommu1844',
#  'percommu1845',
#  'percommu1846',
#  'percommu1847',
#  'percommu1848',
#  'percommu1849',
#  'percommu1850',
#  'percommu1851',
#  'percommu1852',
#  'percommu1853',
#  'percommu1854',
#  'percommu1855',
#  'percommu1856',
#  'percommu1857',
#  'percommu1858',
#  'percommu1859',
#  'percommu1860',
#  'percommu1861',
#  'percommu1862',
#  'percommu1863',
#  'percommu1864',
#  'percommu1865',
#  'percommu1866',
#  'percommu1867',
#  'percommu1868',
#  'percommu1869',
#  'percommu1870',
#  'percommu1871',
#  'percommu1872',
#  'percommu1873',
#  'percommu1874',
#  'percommu1875',
#  'percommu1876',
#  'percommu1877',
#  'percommu1878',
#  'percommu1879',
#  'percommu1880',
#  'percommu1881',
#  'percommu1882',
#  'percommu1883',
#  'percommu1884',
#  'percommu1885',
#  'percommu1886',
#  'percommu1887',
#  'percommu1888',
#  'percommu1889',
#  'percommu1890',
#  'percommu1891',
#  'percommu1892',
#  'percommu1893',
#  'percommu1894',
#  'percommu1895',
#  'percommu1896',
#  'percommu1897',
#  'percommu1898',
#  'percommu1899',
#  'percommu1900',
#  'percommu1901',
#  'percommu1902',
#  'percommu1903',
#  'percommu1904',
#  'percommu1905',
#  'percommu1906',
#  'percommu1907',
#  'percommu1908',
#  'percommu1909',
#  'percommu1910',
#  'percommu1911',
#  'percommu1912',
#  'percommu1913',
#  'percommu1914',
#  'percommu1915',
#  'percommu1916',
#  'percommu1917',
#  'percommu1918',
#  'percommu1919',
#  'percommu1920',
#  'percommu1921',
#  'percommu1922',
#  'percommu1923',
#  'percommu1924',
#  'percommu1925',
#  'percommu1926',
#  'percommu1927',
#  'percommu1928',
#  'percommu1929',
#  'percommu1930',
#  'percommu1931',
#  'percommu1932',
#  'percommu1933',
#  'percommu1934',
#  'percommu1935',
#  'percommu1936',
#  'percommu1937',
#  'percommu1938',
#  'percommu1939',
#  'percommu1940',
#  'percommu1941',
#  'percommu1942',
#  'percommu1943',
#  'percommu1944',
#  'percommu1945',
#  'percommu1946',
#  'percommu1947',
#  'percommu1948',
#  'percommu1949',
#  'percommu1950',
#  'percommu1951',
#  'percommu1952',
#  'percommu1953',
#  'percommu1954',
#  'percommu1955',
#  'percommu1956',
#  'percommu1957',
#  'percommu1958',
#  'percommu1959',
#  'percommu1960',
#  'percommu1961',
#  'percommu1962',
#  'percommu1963',
#  'percommu1964',
#  'percommu1965',
#  'percommu1966',
#  'percommu1967',
#  'percommu1968',
#  'percommu1969',
#  'percommu1970',
#  'percommu1971',
#  'percommu1972',
#  'percommu1973',
#  'percommu1974',
#  'percommu1975',
#  'percommu1976',
#  'percommu1977',
#  'percommu1978',
#  'percommu1979',
#  'percommu1980',
#  'percommu1981',
#  'percommu1982',
#  'percommu1983',
#  'percommu1984',
#  'percommu1985',
#  'percommu1986',
#  'percommu1987',
#  'percommu1988',
#  'percommu1989',
#  'percommu1990',
#  'percommu1991',
#  'percommu1992',
#  'percommu1993',
#  'percommu1994',
#  'percommu1995',
#  'percommu1996',
#  'percommu1997',
#  'percommu1998',
#  'percommu1999',
#  'percommu2000',
#  'percommu2001',
#  'percommu2002',
#  'percommu2003',
#  'percommu2004',
#  'percommu2005',
#  'percommu2006',
#  'percommu2007',
#  'percommu2008',
#  'percommu2009',
#  'percommu2010',
#  'percommu2011',
#  'percommu2012',
#  'percommu2013',
#  'percommu2014',
#  'percommu2015',
#  'percommu2016',
#  'percommu2017',
#  'percommu2018',
#  'percommu2019',
#  'percommu2020',
#  'percommu2021',
#  'percommu2022',
#  'peragglo1780',
#  'peragglo1781',
#  'peragglo1782',
#  'peragglo1783',
#  'peragglo1784',
#  'peragglo1785',
#  'peragglo1786',
#  'peragglo1787',
#  'peragglo1788',
#  'peragglo1789',
#  'peragglo1790',
#  'peragglo1791',
#  'peragglo1792',
#  'peragglo1793',
#  'peragglo1794',
#  'peragglo1795',
#  'peragglo1796',
#  'peragglo1797',
#  'peragglo1798',
#  'peragglo1799',
#  'peragglo1800',
#  'peragglo1801',
#  'peragglo1802',
#  'peragglo1803',
#  'peragglo1804',
#  'peragglo1805',
#  'peragglo1806',
#  'peragglo1807',
#  'peragglo1808',
#  'peragglo1809',
#  'peragglo1810',
#  'peragglo1811',
#  'peragglo1812',
#  'peragglo1813',
#  'peragglo1814',
#  'peragglo1815',
#  'peragglo1816',
#  'peragglo1817',
#  'peragglo1818',
#  'peragglo1819',
#  'peragglo1820',
#  'peragglo1821',
#  'peragglo1822',
#  'peragglo1823',
#  'peragglo1824',
#  'peragglo1825',
#  'peragglo1826',
#  'peragglo1827',
#  'peragglo1828',
#  'peragglo1829',
#  'peragglo1830',
#  'peragglo1831',
#  'peragglo1832',
#  'peragglo1833',
#  'peragglo1834',
#  'peragglo1835',
#  'peragglo1836',
#  'peragglo1837',
#  'peragglo1838',
#  'peragglo1839',
#  'peragglo1840',
#  'peragglo1841',
#  'peragglo1842',
#  'peragglo1843',
#  'peragglo1844',
#  'peragglo1845',
#  'peragglo1846',
#  'peragglo1847',
#  'peragglo1848',
#  'peragglo1849',
#  'peragglo1850',
#  'peragglo1851',
#  'peragglo1852',
#  'peragglo1853',
#  'peragglo1854',
#  'peragglo1855',
#  'peragglo1856',
#  'peragglo1857',
#  'peragglo1858',
#  'peragglo1859',
#  'peragglo1860',
#  'peragglo1861',
#  'peragglo1862',
#  'peragglo1863',
#  'peragglo1864',
#  'peragglo1865',
#  'peragglo1866',
#  'peragglo1867',
#  'peragglo1868',
#  'peragglo1869',
#  'peragglo1870',
#  'peragglo1871',
#  'peragglo1872',
#  'peragglo1873',
#  'peragglo1874',
#  'peragglo1875',
#  'peragglo1876',
#  'peragglo1877',
#  'peragglo1878',
#  'peragglo1879',
#  'peragglo1880',
#  'peragglo1881',
#  'peragglo1882',
#  'peragglo1883',
#  'peragglo1884',
#  'peragglo1885',
#  'peragglo1886',
#  'peragglo1887',
#  'peragglo1888',
#  'peragglo1889',
#  'peragglo1890',
#  'peragglo1891',
#  'peragglo1892',
#  'peragglo1893',
#  'peragglo1894',
#  'peragglo1895',
#  'peragglo1896',
#  'peragglo1897',
#  'peragglo1898',
#  'peragglo1899',
#  'peragglo1900',
#  'peragglo1901',
#  'peragglo1902',
#  'peragglo1903',
#  'peragglo1904',
#  'peragglo1905',
#  'peragglo1906',
#  'peragglo1907',
#  'peragglo1908',
#  'peragglo1909',
#  'peragglo1910',
#  'peragglo1911',
#  'peragglo1912',
#  'peragglo1913',
#  'peragglo1914',
#  'peragglo1915',
#  'peragglo1916',
#  'peragglo1917',
#  'peragglo1918',
#  'peragglo1919',
#  'peragglo1920',
#  'peragglo1921',
#  'peragglo1922',
#  'peragglo1923',
#  'peragglo1924',
#  'peragglo1925',
#  'peragglo1926',
#  'peragglo1927',
#  'peragglo1928',
#  'peragglo1929',
#  'peragglo1930',
#  'peragglo1931',
#  'peragglo1932',
#  'peragglo1933',
#  'peragglo1934',
#  'peragglo1935',
#  'peragglo1936',
#  'peragglo1937',
#  'peragglo1938',
#  'peragglo1939',
#  'peragglo1940',
#  'peragglo1941',
#  'peragglo1942',
#  'peragglo1943',
#  'peragglo1944',
#  'peragglo1945',
#  'peragglo1946',
#  'peragglo1947',
#  'peragglo1948',
#  'peragglo1949',
#  'peragglo1950',
#  'peragglo1951',
#  'peragglo1952',
#  'peragglo1953',
#  'peragglo1954',
#  'peragglo1955',
#  'peragglo1956',
#  'peragglo1957',
#  'peragglo1958',
#  'peragglo1959',
#  'peragglo1960',
#  'peragglo1961',
#  'peragglo1962',
#  'peragglo1963',
#  'peragglo1964',
#  'peragglo1965',
#  'peragglo1966',
#  'peragglo1967',
#  'peragglo1968',
#  'peragglo1969',
#  'peragglo1970',
#  'peragglo1971',
#  'peragglo1972',
#  'peragglo1973',
#  'peragglo1974',
#  'peragglo1975',
#  'peragglo1976',
#  'peragglo1977',
#  'peragglo1978',
#  'peragglo1979',
#  'peragglo1980',
#  'peragglo1981',
#  'peragglo1982',
#  'peragglo1983',
#  'peragglo1984',
#  'peragglo1985',
#  'peragglo1986',
#  'peragglo1987',
#  'peragglo1988',
#  'peragglo1989',
#  'peragglo1990',
#  'peragglo1991',
#  'peragglo1992',
#  'peragglo1993',
#  'peragglo1994',
#  'peragglo1995',
#  'peragglo1996',
#  'peragglo1997',
#  'peragglo1998',
#  'peragglo1999',
#  'peragglo2000',
#  'peragglo2001',
#  'peragglo2002',
#  'peragglo2003',
#  'peragglo2004',
#  'peragglo2005',
#  'peragglo2006',
#  'peragglo2007',
#  'peragglo2008',
#  'peragglo2009',
#  'peragglo2010',
#  'peragglo2011',
#  'peragglo2012',
#  'peragglo2013',
#  'peragglo2014',
#  'peragglo2015',
#  'peragglo2016',
#  'peragglo2017',
#  'peragglo2018',
#  'peragglo2019',
#  'peragglo2020',
#  'peragglo2021',
#  'peragglo2022']

# %%
df_demographie_filtre = df_demographie.filter(regex="^dep$|^codecommune$|^reg$|^pop[0-9]{4}$")
df_demographie_filtre
# Out:
#       dep codecommune reg  pop1780  pop1781  pop1782  pop1783  pop1784  \
# 0      01       01001  84    511.0    512.0    512.0    513.0    513.0
# 1      01       01002  84    409.0    410.0    410.0    411.0    411.0
# 2      01       01004  84   2452.0   2454.0   2457.0   2459.0   2462.0
# 3      01       01005  84    718.0    718.0    719.0    720.0    721.0
# 4      01       01006  84    162.0    162.0    162.0    162.0    162.0
# ...    ..         ...  ..      ...      ...      ...      ...      ...
# 34851  95       95676  11    332.0    332.0    333.0    333.0    333.0
# 34852  95       95678  11    276.0    276.0    277.0    277.0    277.0
# 34853  95       95680  11   1253.0   1255.0   1256.0   1257.0   1258.0
# 34854  95       95682  11    147.0    147.0    147.0    147.0    147.0
# 34855  95       95690  11    221.0    222.0    222.0    222.0    222.0
#
#        pop1785  pop1786  ...  pop2013  pop2014  pop2015  pop2016  pop2017  \
# 0        514.0    514.0  ...    767.0    767.0    767.0    767.0    776.0
# 1        411.0    412.0  ...    236.0    239.0    241.0    243.0    248.0
# 2       2464.0   2467.0  ...  14359.0  14022.0  14127.0  14081.0  14035.0
# 3        721.0    722.0  ...   1635.0   1627.0   1619.0   1671.0   1689.0
# 4        162.0    163.0  ...    108.0    109.0    109.0    110.0    111.0
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 34851    334.0    334.0  ...    492.0    503.0    508.0    506.0    503.0
# 34852    278.0    278.0  ...    843.0    838.0    851.0    863.0    859.0
# 34853   1260.0   1261.0  ...  27312.0  27571.0  27564.0  27247.0  27676.0
# 34854    148.0    148.0  ...    179.0    177.0    179.0    183.0    185.0
# 34855    222.0    223.0  ...    309.0    318.0    326.0    335.0    333.0
#
#        pop2018  pop2019  pop2020  pop2021  pop2022
# 0        771.0    779.0    781.0    784.0    786.0
# 1        253.0    256.0    259.0    263.0    266.0
# 2      14204.0  14134.0  14156.0  14179.0  14201.0
# 3       1720.0   1751.0   1776.0   1801.0   1825.0
# 4        112.0    112.0    113.0    113.0    114.0
# ...        ...      ...      ...      ...      ...
# 34851    497.0    490.0    487.0    485.0    482.0
# 34852    861.0    861.0    866.0    870.0    875.0
# 34853  28041.0  28423.0  28593.0  28764.0  28934.0
# 34854    187.0    189.0    191.0    194.0    196.0
# 34855    332.0    330.0    332.0    335.0    337.0
#
# [34856 rows x 246 columns]

# %%
df_faits = pd.DataFrame(columns=["population"])

df_dimension_commune = pd.DataFrame(columns=["code_departement", "code_commune", "code_region", "annee"])df_dimension_commune
for idx, row in df_demographie_filtre.iterrows():
    for index, value in row.filter(regex="^pop[0-9]{4}$").items():
        df_faits.loc[len(df_faits)] = [value]
        df_dimensions.loc[len(df_dimensions)] = [row["dep"], row["codecommune"], row["reg"], index[-4:]]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_150/1212490778.py in ?()
#       3
#       4 for idx, row in df_demographie_filtre.iterrows():
#       5     for index, value in row.filter(regex="^pop[0-9]{4}$").items():
#       6         df_faits.loc[len(df_faits)] = [value]
# ----> 7         df_dimensions.loc[len(df_dimensions)] = [row["dep"], row["codecommune"], row["reg"], index[-4:]]
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py in ?(self, key, value)
#     845         indexer = self._get_setitem_indexer(key)
#     846         self._has_valid_setitem_indexer(key)
#     847
#     848         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849         iloc._setitem_with_indexer(indexer, value, self.name)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py in ?(self, indexer, value, name)
#    1821         else:
#    1822             indexer, missing = convert_missing_indexer(indexer)
#    1823
#    1824             if missing:
# -> 1825                 self._setitem_with_indexer_missing(indexer, value)
#    1826                 return
#    1827
#    1828         if name == "loc":
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/indexing.py in ?(self, indexer, value)
#    2176                     #  dtype.  But if we had a list or dict, then do inference
#    2177                     df = df.infer_objects(copy=False)
#    2178                 self.obj._mgr = df._mgr
#    2179             else:
# -> 2180                 self.obj._mgr = self.obj._append(value)._mgr
#    2181             self.obj._maybe_update_cacher(clear=True)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, other, ignore_index, verify_integrity, sort)
#    9554             to_concat = [self, *other]
#    9555         else:
#    9556             to_concat = [self, other]
#    9557
# -> 9558         result = concat(
#    9559             to_concat,
#    9560             ignore_index=ignore_index,
#    9561             verify_integrity=verify_integrity,
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/concat.py in ?(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     368             copy = True
#     369     elif copy and using_copy_on_write():
#     370         copy = False
#     371
# --> 372     op = _Concatenator(
#     373         objs,
#     374         axis=axis,
#     375         ignore_index=ignore_index,
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/concat.py in ?(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     476
#     477         else:
#     478             # filter out the empties if we have not multi-index possibilities
#     479             # note to keep empty Series as it affect to result columns / name
# --> 480             non_empties = [
#     481                 obj for obj in objs if sum(obj.shape) > 0 or isinstance(obj, ABCSeries)
#     482             ]
#     483
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/concat.py in ?(.0)
#     480     def __init__(
# --> 481         self,
#     482         objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#     483         axis: Axis = 0,
#     484         join: str = "outer",
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py in ?(self)
# --> 910     @property
#     911     def shape(self) -> tuple[int, int]:
#     912         """
#     913         Return a tuple representing the dimensionality of the DataFrame.
#
# KeyboardInterrupt:

# %%
df_faits

# %%
df_dimensions

# %% [markdown]
# # Générer une table au format CSV avec une description statistique du DataFrame

# %%
# df.describe().toPandas().to_csv("describe_summary.csv", index=False)

# %% [markdown]
# # Effectuer un échantillonage du DataFrame pour en observer les colonnes qui peuvent sembler pertinentes

# %%
FRACTION_SIZE = 0.00001

# %%
columnsToSample = ['quantity', 'serving_size', 'serving_quantity', 'product_quantity']

# %%
samples_not_clean_df = df.select(columnsToSample).dropna(how='all').cache()

# %%
samples_df = samples_not_clean_df.sample(withReplacement=False, fraction=FRACTION_SIZE).cache()

# %%
samples_df.count()
# Out:
# 16

# %%
samples_df.show()
# Out:
# +--------+-----------------+----------------+----------------+
# |quantity|     serving_size|serving_quantity|product_quantity|
# +--------+-----------------+----------------+----------------+
# |    NULL|8.45 OZA (250 ml)|           250.0|            NULL|
# |    NULL| 0.5 cup (120 ml)|           120.0|            NULL|
# |    NULL|           340.0g|           340.0|            NULL|
# |    NULL|    1 OZA (30 ml)|            30.0|            NULL|
# |    NULL|   14 ONZ (396 g)|           396.0|            NULL|
# |   270 g|             NULL|            NULL|           270.0|
# |   100 g|             NULL|            NULL|           100.0|
# |    300g|             NULL|            NULL|           300.0|
# |   500 g|             NULL|            NULL|           500.0|
# |   20 oz|             NULL|            NULL|     566.9904625|
# |  2000 g|             NULL|            NULL|          2000.0|
# |   100 g|       30 g (3 u)|            NULL|           100.0|
# |   500 g|             NULL|            NULL|           500.0|
# |    NULL|             100g|           100.0|            NULL|
# |   150 g|             NULL|            NULL|           150.0|
# |   180ml|             180g|           180.0|           180.0|
# +--------+-----------------+----------------+----------------+

# %% [markdown]
# # Extraire les valeurs uniques d'une colonne afin d'en confirmer la pertinence (colonne ingredients_analysis_tags en exemple)

# %%
def flatten_list(li):
    flat_list = []
    for row in li:
        flat_list += row
    return flat_list

def make_list_unique(li):
    return list(dict.fromkeys(li))

def split_string_list_elements(li, sep):
    return [x.split(sep) for x in li]

def column_to_list(col):
    return col.rdd.flatMap(lambda x: x).collect()

# %%
ingredients_analysis_list = make_list_unique(flatten_list(split_string_list_elements(column_to_list(df.select('ingredients_analysis_tags').dropna()), ",")))

# %%
ingredients_analysis_list
# Out:
# ['en:palm-oil-free',
#  'en:non-vegan',
#  'en:vegetarian-status-unknown',
#  'en:palm-oil-content-unknown',
#  'en:vegan-status-unknown',
#  'en:may-contain-palm-oil',
#  'en:vegetarian',
#  'en:vegan',
#  'en:non-vegetarian',
#  'en:palm-oil',
#  'en:maybe-vegan',
#  'en:maybe-vegetarian']

# %% [markdown]
# # Sélection des colonnes nécessaires après étude de celles-ci

# %%
kept_columns = ["code", "product_name", "product_quantity", "energy-kcal_100g", "fat_100g", "saturated-fat_100g", "monounsaturated-fat_100g", "polyunsaturated-fat_100g", "trans-fat_100g", 
                "carbohydrates_100g", "sugars_100g", "starch_100g", "fiber_100g", "proteins_100g", "allergens", "traces", "vitamin-a_100g", "vitamin-c_100g", "vitamin-d_100g",
                "vitamin-e_100g", "vitamin-k_100g", "vitamin-b1_100g", "vitamin-b2_100g", "vitamin-b6_100g", "vitamin-b9_100g", "vitamin-b12_100g", "calcium_100g",
                "iron_100g", "magnesium_100g", "potassium_100g", "zinc_100g", "food_groups_tags", "serving_size", "serving_quantity", "cholesterol_100g", "salt_100g", "glycemic-index_100g"]

# %%
df_kept_columns = df.select(kept_columns)

# %% [markdown]
# # Qualité des données

# %% [markdown]
# ## On supprime les lignes qui ont moins de 15 colonnes très pertinentes non nulles

# %%
columns_to_check = ["code", "product_name", "product_quantity", "energy-kcal_100g", "fat_100g", "saturated-fat_100g", "monounsaturated-fat_100g",
                    "polyunsaturated-fat_100g", "trans-fat_100g", "carbohydrates_100g", "sugars_100g", "starch_100g", 
                    "fiber_100g", "proteins_100g", "allergens", "traces", "food_groups_tags", "serving_size", "serving_quantity"]

# %%
df_kept_columns = df_kept_columns.dropna(subset=columns_to_check, thresh=15)

# %% [markdown]
# ## On supprime les lignes dupliquées et on garde le DF en cache pour éviter de le recalculer

# %%
df_kept_columns = df_kept_columns.dropDuplicates().cache()

# %%
print("Nombre de lignes restantes après le traitement : " + str(df_kept_columns.count()))
# Out:
# Nombre de lignes restantes après le traitement : 65401

# %% [markdown]
# ## Plus besoin du DataFrame de base donc on le retire de la mémoire cache

# %%
df.unpersist()
print("Mémoire libérée")
# Out:
# Mémoire libérée

# %% [markdown]
# # Écriture des données nettoyées en base de données avec le driver JDBC

# %%
properties = {
    "user": "user",
    "password": "userpassword",
    "driver": "com.mysql.cj.jdbc.Driver"
}

df_kept_columns.write.jdbc(url="jdbc:mysql://mysql:3306/openfoodfact", table="products", mode="append", properties=properties)
