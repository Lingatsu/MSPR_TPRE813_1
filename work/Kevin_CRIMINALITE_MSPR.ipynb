# %% [markdown]
# # Data delinquance

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Delinquance

# %%
path="/content/drive/MyDrive/Cours_EPSI/MSPR/MSPR_TPRE813_1/data/Criminalite/donnee-comm-data.gouv-parquet-2023-geographie2024-produit-le2024-07-05.parquet"
delinquance_brut = pd.read_parquet(path, engine='pyarrow')
#filtrage par rapport à une valeur de code commune pour verifier la bonne presence de celle-ci
delinquance_brut[delinquance_brut['CODGEO_2024'] == '13206']
# Out:
#         CODGEO_2024  annee                                         classe  \
# 61768         13206     16                 Coups et blessures volontaires
# 61769         13206     16  Coups et blessures volontaires intrafamiliaux
# 61770         13206     16          Autres coups et blessures volontaires
# 61771         13206     16                            Violences sexuelles
# 61772         13206     16                                Vols avec armes
# ...             ...    ...                                            ...
# 3489817       13206     23                        Vols dans les véhicules
# 3489818       13206     23               Vols d'accessoires sur véhicules
# 3489819       13206     23       Destructions et dégradations volontaires
# 3489820       13206     23                          Trafic de stupéfiants
# 3489821       13206     23                           Usage de stupéfiants
#
#         unité.de.compte valeur.publiée  faits  tauxpourmille  \
# 61768           victime           diff  289.0       6.710007
# 61769           victime           diff  100.0       2.321802
# 61770           victime           diff  189.0       4.388205
# 61771           victime           diff   47.0       1.091247
# 61772        infraction           diff   25.0       0.580450
# ...                 ...            ...    ...            ...
# 3489817        véhicule           diff  977.0      24.642470
# 3489818        véhicule           diff  108.0       2.724040
# 3489819      infraction           diff  537.0      13.544530
# 3489820    Mis en cause           diff   86.0       2.169143
# 3489821    Mis en cause           diff  910.0      22.952556
#
#          complementinfoval  complementinfotaux    POP  millPOP           LOG  \
# 61768                  NaN                 NaN  43070       16  26958.736388
# 61769                  NaN                 NaN  43070       16  26958.736388
# 61770                  NaN                 NaN  43070       16  26958.736388
# 61771                  NaN                 NaN  43070       16  26958.736388
# 61772                  NaN                 NaN  43070       16  26958.736388
# ...                    ...                 ...    ...      ...           ...
# 3489817                NaN                 NaN  39647       21  27651.762234
# 3489818                NaN                 NaN  39647       21  27651.762234
# 3489819                NaN                 NaN  39647       21  27651.762234
# 3489820                NaN                 NaN  39647       21  27651.762234
# 3489821                NaN                 NaN  39647       21  27651.762234
#
#          millLOG
# 61768         16
# 61769         16
# 61770         16
# 61771         16
# 61772         16
# ...          ...
# 3489817       21
# 3489818       21
# 3489819       21
# 3489820       21
# 3489821       21
#
# [112 rows x 13 columns]

# %%
delinquance_drop = delinquance_brut.drop(columns=['millPOP','millLOG','classe', 'unité.de.compte',	'valeur.publiée',	'complementinfoval',	'complementinfotaux',	'POP', 'LOG'])
delinquance_drop.tail()
# Out:
#         CODGEO_2024  annee  faits  tauxpourmille
# 3917755       97617     23   19.0       1.363571
# 3917756       97617     23    NaN            NaN
# 3917757       97617     23   87.0       6.243720
# 3917758       97617     23    NaN            NaN
# 3917759       97617     23    NaN            NaN

# %%
delinquance_rename = delinquance_drop.rename(columns={'CODGEO_2024' : 'codecommune','LIBGEO' : 'nomcommune','DEP' : 'dep', 'REG' : 'reg'})
delinquance_rename
# Out:
#         codecommune  annee  faits  tauxpourmille
# 0             01001     16    NaN            NaN
# 1             01001     16    0.0       0.000000
# 2             01001     16    NaN            NaN
# 3             01001     16    0.0       0.000000
# 4             01001     16    0.0       0.000000
# ...             ...    ...    ...            ...
# 3917755       97617     23   19.0       1.363571
# 3917756       97617     23    NaN            NaN
# 3917757       97617     23   87.0       6.243720
# 3917758       97617     23    NaN            NaN
# 3917759       97617     23    NaN            NaN
#
# [3917760 rows x 4 columns]

# %%
delinquance_drop_na = delinquance_rename.dropna(subset=['annee'])
delinquance_drop_na
# Out:
#         codecommune  annee  faits  tauxpourmille
# 0             01001     16    NaN            NaN
# 1             01001     16    0.0       0.000000
# 2             01001     16    NaN            NaN
# 3             01001     16    0.0       0.000000
# 4             01001     16    0.0       0.000000
# ...             ...    ...    ...            ...
# 3917755       97617     23   19.0       1.363571
# 3917756       97617     23    NaN            NaN
# 3917757       97617     23   87.0       6.243720
# 3917758       97617     23    NaN            NaN
# 3917759       97617     23    NaN            NaN
#
# [3917760 rows x 4 columns]

# %%
# conversion de string à int avec regex pour eviter les problèmes de changement de valeurs de base 10 (ex: 2A001 au lieu de 1001 par exemple)
delinquance_drop_na['codecommune'] = delinquance_drop_na['codecommune'].str.replace('[^0-9]', '', regex=True).astype('int64')

# retire les premiers 0 pour mettre au même format que les DF de mes camarades
delinquance_drop_na['annee'] = delinquance_drop_na['annee'].astype(str)
delinquance_drop_na['annee'] = delinquance_drop_na['annee'].str.replace('.0','')
delinquance_drop_na['annee'] = '20' + delinquance_drop_na['annee']
delinquance_drop_na['annee'] = delinquance_drop_na['annee'].str.replace('[^0-9]', '', regex=True).astype('int64')
delinquance_drop_na
# Out:
#          codecommune  annee  faits  tauxpourmille
# 0               1001   2016    NaN            NaN
# 1               1001   2016    0.0       0.000000
# 2               1001   2016    NaN            NaN
# 3               1001   2016    0.0       0.000000
# 4               1001   2016    0.0       0.000000
# ...              ...    ...    ...            ...
# 3917755        97617   2023   19.0       1.363571
# 3917756        97617   2023    NaN            NaN
# 3917757        97617   2023   87.0       6.243720
# 3917758        97617   2023    NaN            NaN
# 3917759        97617   2023    NaN            NaN
#
# [3917760 rows x 4 columns]

# %%
# On groupe les colonnes et on somme la colonne 'faits'
df_grouped = delinquance_drop_na.groupby(['codecommune','annee'])['faits'].sum().reset_index()

df_grouped.head(50)
# Out:
#     codecommune  annee  faits
# 0          1001   2016    0.0
# 1          1001   2017    0.0
# 2          1001   2018    0.0
# 3          1001   2019    0.0
# 4          1001   2020    0.0
# 5          1001   2021    0.0
# 6          1001   2022    0.0
# 7          1001   2023    0.0
# 8          1002   2016    0.0
# 9          1002   2017    0.0
# 10         1002   2018    0.0
# 11         1002   2019    0.0
# 12         1002   2020    0.0
# 13         1002   2021    0.0
# 14         1002   2022    0.0
# 15         1002   2023    0.0
# 16         1004   2016  642.0
# 17         1004   2017  643.0
# 18         1004   2018  718.0
# 19         1004   2019  726.0
# 20         1004   2020  610.0
# 21         1004   2021  646.0
# 22         1004   2022  806.0
# 23         1004   2023  643.0
# 24         1005   2016   17.0
# 25         1005   2017   15.0
# 26         1005   2018   18.0
# 27         1005   2019   11.0
# 28         1005   2020    8.0
# 29         1005   2021    6.0
# 30         1005   2022   23.0
# 31         1005   2023   19.0
# 32         1006   2016    0.0
# 33         1006   2017    0.0
# 34         1006   2018    0.0
# 35         1006   2019    0.0
# 36         1006   2020    0.0
# 37         1006   2021    0.0
# 38         1006   2022    0.0
# 39         1006   2023    0.0
# 40         1007   2016   48.0
# 41         1007   2017   39.0
# 42         1007   2018   98.0
# 43         1007   2019   75.0
# 44         1007   2020   57.0
# 45         1007   2021   51.0
# 46         1007   2022   47.0
# 47         1007   2023   71.0
# 48         1008   2016    0.0
# 49         1008   2017    0.0

# %%
df_grouped['faits']=df_grouped['faits'].astype('int64')
df_grouped.head(50)
# Out:
#     codecommune  annee  faits
# 0          1001   2016      0
# 1          1001   2017      0
# 2          1001   2018      0
# 3          1001   2019      0
# 4          1001   2020      0
# 5          1001   2021      0
# 6          1001   2022      0
# 7          1001   2023      0
# 8          1002   2016      0
# 9          1002   2017      0
# 10         1002   2018      0
# 11         1002   2019      0
# 12         1002   2020      0
# 13         1002   2021      0
# 14         1002   2022      0
# 15         1002   2023      0
# 16         1004   2016    642
# 17         1004   2017    643
# 18         1004   2018    718
# 19         1004   2019    726
# 20         1004   2020    610
# 21         1004   2021    646
# 22         1004   2022    806
# 23         1004   2023    643
# 24         1005   2016     17
# 25         1005   2017     15
# 26         1005   2018     18
# 27         1005   2019     11
# 28         1005   2020      8
# 29         1005   2021      6
# 30         1005   2022     23
# 31         1005   2023     19
# 32         1006   2016      0
# 33         1006   2017      0
# 34         1006   2018      0
# 35         1006   2019      0
# 36         1006   2020      0
# 37         1006   2021      0
# 38         1006   2022      0
# 39         1006   2023      0
# 40         1007   2016     48
# 41         1007   2017     39
# 42         1007   2018     98
# 43         1007   2019     75
# 44         1007   2020     57
# 45         1007   2021     51
# 46         1007   2022     47
# 47         1007   2023     71
# 48         1008   2016      0
# 49         1008   2017      0
